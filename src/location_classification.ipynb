# %% [markdown]
# ## Import dependencies

# %%
# !nvidia-smi
# Out:
# Sun Jan 21 10:15:19 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torchvision
import time
import os
import copy
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt
import imageio as iio
import imgaug.augmenters as ia
import imgaug
import shutil

from tqdm import tqdm
from pathlib import Path
from PIL import Image, ImageOps


import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
from torch.utils.data import random_split

# %% [markdown]
# # Data Augmentation

# %%
data_dir = '/content/drive/MyDrive/Xu ly anh /Group_Thanh_Ha/dataset'

class_names = sorted(os.listdir(data_dir))

iter = ['/' + class_name for class_name in class_names]

# %%
sometimes = lambda aug: ia.Sometimes(0.5, aug)

# Define our sequence of augmentation steps that will be applied to every image.
seq = ia.Sequential(
    [
        #
        # Apply the following augmenters to most images.
        #
        #ia.Fliplr(0.5), # horizontally flip 50% of all images
        #ia.Flipud(0.2), # vertically flip 20% of all images

        # crop some of the images by 0-10% of their height/width
        #sometimes(ia.Crop(percent=(0, 0.1))),

        # Apply affine transformations to some of the images
        # - scale to 80-120% of image height/width (each axis independently)
        # - translate by -20 to +20 relative to height/width (per axis)
        # - rotate by -45 to +45 degrees
        # - shear by -16 to +16 degrees
        # - order: use nearest neighbour or bilinear interpolation (fast)
        # - mode: use any available mode to fill newly created pixels
        #         see API or scikit-image for which modes are available
        # - cval: if the mode is constant, then use a random brightness
        #         for the newly created pixels (e.g. sometimes black,
        #         sometimes white)
        sometimes(ia.Affine(
            #scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
            translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
            #rotate=(-45, 45),
            shear=(-16, 16),
            order=[0, 1],
            cval=(0, 255),
            mode=imgaug.ALL
        )),

        #
        # Execute 0 to 5 of the following (less important) augmenters per
        # image. Don't execute all of them, as that would often be way too
        # strong.
        #
        ia.SomeOf((0, 5),
            [
                # Convert some images into their superpixel representation,
                # sample between 20 and 200 superpixels per image, but do
                # not replace all superpixels with their average, only
                # some of them (p_replace).
                sometimes(
                    ia.Superpixels(
                        p_replace=(0, 1.0),
                        n_segments=(20, 200)
                    )
                ),

                # Blur each image with varying strength using
                # gaussian blur (sigma between 0 and 3.0),
                # average/uniform blur (kernel size between 2x2 and 7x7)
                # median blur (kernel size between 3x3 and 11x11).
                ia.OneOf([
                    ia.GaussianBlur((0, 3.0)),
                    ia.AverageBlur(k=(2, 7)),
                    ia.MedianBlur(k=(3, 11)),
                ]),

                # Sharpen each image, overlay the result with the original
                # image using an alpha between 0 (no sharpening) and 1
                # (full sharpening effect).
                ia.Sharpen(alpha=(0, 1.0), lightness=(0.75, 1.5)),

                # Same as sharpen, but for an embossing effect.
                ia.Emboss(alpha=(0, 1.0), strength=(0, 2.0)),

                # Search in some images either for all edges or for
                # directed edges. These edges are then marked in a black
                # and white image and overlayed with the original image
                # using an alpha of 0 to 0.7.
                sometimes(ia.OneOf([
                    ia.EdgeDetect(alpha=(0, 0.7)),
                    ia.DirectedEdgeDetect(
                        alpha=(0, 0.7), direction=(0.0, 1.0)
                    ),
                ])),

                # Add gaussian noise to some images.
                # In 50% of these cases, the noise is randomly sampled per
                # channel and pixel.
                # In the other 50% of all cases it is sampled once per
                # pixel (i.e. brightness change).
                ia.AdditiveGaussianNoise(
                    loc=0, scale=(0.0, 0.05*255), per_channel=0.5
                ),

                # Either drop randomly 1 to 10% of all pixels (i.e. set
                # them to black) or drop them on an image with 2-5% percent
                # of the original size, leading to large dropped
                # rectangles.
                ia.OneOf([
                    ia.Dropout((0.01, 0.1), per_channel=0.5),
                    ia.CoarseDropout(
                        (0.03, 0.15), size_percent=(0.02, 0.05),
                        per_channel=0.2
                    ),
                ]),

                # Invert each image's channel with 5% probability.
                # This sets each pixel value v to 255-v.
                #ia.Invert(0.05, per_channel=True), # invert color channels

                # Add a value of -10 to 10 to each pixel.
                #ia.Add((-10, 10), per_channel=0.5),

                # Change brightness of images (50-150% of original value).
                ia.Multiply((0.5, 1.5), per_channel=0.5),

                # Improve or worsen the contrast of images.
                ia.LinearContrast((0.5, 2.0), per_channel=0.5),

                # Convert each image to grayscale and then overlay the
                # result with the original with random alpha. I.e. remove
                # colors with varying strengths.
                #ia.Grayscale(alpha=(0.0, 1.0)),

                # In some images move pixels locally around (with random
                # strengths).
                sometimes(
                    ia.ElasticTransformation(alpha=(0.5, 3.5), sigma=0.25)
                ),

                # In some images distort local areas with varying strength.
                # sometimes(ia.PiecewiseAffine(scale=(0.01, 0.05)))
            ],
            # do all of the above augmentations in random order
            random_order=True
        )
    ],
    # do all of the above augmentations in random order
    random_order=True)

def sequence(source, target, num):
    for i in iter:
        if len(os.listdir(Path(target + "/" + i))):
          continue
        count = 0
        for file in Path(source + "/" + i).iterdir():
            img = iio.imread(file)
            count += 1
            for k in tqdm(range(num)):
                imgnew = seq.augment_image(img);
                imgnew = cv2.cvtColor(imgnew, cv2.COLOR_RGBA2RGB)
                iio.imwrite(target + '/' + i + '/' + str(count) + "_v" + str(k) + '.JPG', imgnew)
        #     iio.imwrite(target + '/' + i + '/' + str(count) + '.JPG', img)
        print(f'Class {i} done!')

# %%
source = '/content/drive/MyDrive/Xu ly anh /Group_Thanh_Ha/dataset'
target = '/content/datadir'

os.makedirs(target, exist_ok=True)

num = 100

for class_name in class_names:
    try:
      os.makedirs(os.path.join(target, class_name), exist_ok=True)
    except:
      pass

for i in iter:
    count = 0
    for file in Path(source + "/" + i).iterdir():
        img = iio.imread(file)
        count += 1
        img = cv2.cvtColor(img, cv2.COLOR_RGBA2RGB)
        iio.imwrite(target + '/' + i + '/' + str(count) + '.JPG', img)
    print(len(os.listdir(Path(target + '/' + i))))

sequence(source, target, num)

# %% [markdown]
# ## Splitting data into training set and testing set

# %%
source = '/content/datadir'
target = '/content/datadir_splitted'

os.makedirs(target, exist_ok=True)

train_dir = f'{target}/train'
valid_dir = f'{target}/valid'

# Create output folders if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(valid_dir, exist_ok=True)

class_folders = os.listdir(source)

# Iterate through each class folder in the input folder
for i in tqdm(range(len(os.listdir(source)))):
    class_path = os.path.join(source, class_folders[i])

    # Skip non-directory entries
    if not os.path.isdir(class_path):
        continue

    # List all files in the class folder
    files = os.listdir(class_path)

    # Shuffle the files with a fixed seed for reproducibility
    random.seed(0)
    random.shuffle(files)

    # Calculate the split index based on the split ratio
    split_index = int(len(files) * 0.8)

    # Split the files into training and validation sets
    train_files = files[:split_index]
    valid_files = files[split_index:]

    # Move files to the corresponding output folders
    for file in train_files:
        src_path = os.path.join(class_path, file)
        dest_path = os.path.join(train_dir, class_folders[i], file)
        os.makedirs(os.path.dirname(dest_path), exist_ok=True)
        shutil.copy(src_path, dest_path)

    for file in valid_files:
        src_path = os.path.join(class_path, file)
        dest_path = os.path.join(valid_dir, class_folders[i], file)
        os.makedirs(os.path.dirname(dest_path), exist_ok=True)
        shutil.copy(src_path, dest_path)

# %% [markdown]
# # Download augmented data

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-5.0.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.11.17)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-5.0.0

# %%
# !gdown --id 1Y9V6qlz5qNSNSHsNWW1NAzm97uN_QrTN
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Y9V6qlz5qNSNSHsNWW1NAzm97uN_QrTN
# From (redirected): https://drive.google.com/uc?id=1Y9V6qlz5qNSNSHsNWW1NAzm97uN_QrTN&confirm=t&uuid=bba3a864-cfa6-4c34-833a-e6ef8c62c904
# To: /content/data_sequence_trial_splitted_2_200.zip
# 100% 1.69G/1.69G [00:14<00:00, 118MB/s]

# %%
# !unzip data_sequence_trial_splitted_2_200
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v71.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v101.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v144.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v118.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v3.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v106.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v174.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v120.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v76.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v53.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v138.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v142.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v13.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v25.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v132.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v45.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v25.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v45.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v174.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v32.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v154.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v16.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v185.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v70.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v110.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v114.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v44.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v29.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v71.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v140.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v152.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v101.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v169.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v183.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v158.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v11.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v188.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v93.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v130.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v72.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v100.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v153.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v64.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v74.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v109.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v67.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v94.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v108.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v163.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v41.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v60.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v95.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v135.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v120.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v22.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v42.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v83.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v159.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v70.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v158.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v58.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v137.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v80.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v191.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v90.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v62.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v181.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v55.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v67.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v41.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v7.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v50.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v139.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v144.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v39.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v76.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v57.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v99.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v18.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v23.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v109.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v137.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v68.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v179.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v23.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v138.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v37.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v62.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v35.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v185.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v170.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v60.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v25.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v132.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v79.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v4.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v31.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v3.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v13.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v54.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v31.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v60.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v107.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v160.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v86.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v30.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v54.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v16.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v188.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v82.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v168.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v147.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v88.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v171.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v141.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v20.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v173.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v151.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v185.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v160.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v88.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v161.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v78.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v105.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v149.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v170.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v33.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v80.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v128.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v12.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v143.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v58.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v145.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v146.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v74.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v104.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v119.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v66.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v180.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v149.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v191.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v29.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v108.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v186.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v155.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v167.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v129.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v30.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v96.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v26.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v195.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v116.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v86.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v56.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v168.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v152.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v168.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v64.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v152.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v167.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v153.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v134.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v125.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v4.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v196.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v136.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v197.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v187.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v77.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v132.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v176.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v101.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v66.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v125.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v192.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v146.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v4.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v40.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v147.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v43.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v90.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v60.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v22.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v115.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v61.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v116.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v114.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v38.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v66.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v163.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v141.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v154.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v117.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v87.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v52.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v121.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v56.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v104.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v127.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v110.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v97.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v74.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v186.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v181.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v89.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v159.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v111.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v57.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v1.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v187.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v38.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v41.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v36.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v37.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v84.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v152.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v120.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v68.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v99.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v105.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v180.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v115.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v16.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v164.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v190.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v46.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v122.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v127.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v56.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v106.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v197.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v189.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v47.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v37.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v28.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v138.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v139.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v39.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v11.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v134.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v163.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v43.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v108.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v194.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v90.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v173.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v154.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v33.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v94.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v55.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v137.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v162.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v183.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v190.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v155.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v164.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v93.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v11.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v106.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v181.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v52.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v84.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v154.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v69.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v63.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v45.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v2.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v35.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v131.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v16.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v45.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v131.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v136.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v2.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v162.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v170.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v131.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v184.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v90.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v25.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v48.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v141.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v179.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v32.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v185.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v4.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v167.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v94.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v54.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v122.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v29.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v66.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v40.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v65.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v107.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v99.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v193.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v123.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v53.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v195.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v119.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v178.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v197.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v182.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v85.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v17.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v176.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v77.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v177.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v77.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v164.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v146.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v48.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v92.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v45.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v49.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v146.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v150.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v51.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v38.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v167.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v123.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v36.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v18.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v190.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v3.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v127.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v198.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v42.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v85.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v125.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v32.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v178.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v69.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v8.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v17.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v143.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v141.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v79.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v83.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v96.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v49.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v39.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v68.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v92.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v8.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v188.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v128.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v17.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v47.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v42.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v13.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v106.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v192.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v112.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v93.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v47.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v121.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v18.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v37.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v89.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v27.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v71.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v117.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v1.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v60.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v88.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v135.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v134.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v115.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v24.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v144.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v65.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v24.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v92.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v6.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v9.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v68.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v50.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v150.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v27.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v151.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v173.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v81.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v72.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v14.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v129.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v174.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v6.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v82.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v198.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v107.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v78.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v13.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v63.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v122.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v62.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v9.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v82.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v109.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v110.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v110.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v187.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v133.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v12.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v22.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v85.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v15.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v95.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v105.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v96.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v127.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v19.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v132.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v148.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v143.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v178.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v52.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v29.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v87.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v160.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v193.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v15.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v3.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v118.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v196.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v198.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v100.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/3_v49.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v180.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v140.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v31.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v196.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v177.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v138.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/5_v113.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/4_v120.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v113.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/2_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v123.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_hotel/1_v111.JPG
#    creating: data_sequence_trial_2_200/train/losing_ground_rental_house/
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v91.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v137.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v188.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v70.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v114.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v90.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v142.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v128.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v195.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v128.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v139.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v199.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v24.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v169.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v196.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v150.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v83.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v75.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v50.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v89.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v41.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v125.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v153.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v36.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v1.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v183.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v88.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v59.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v85.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v140.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v58.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v33.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v186.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v108.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v26.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v46.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v31.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v111.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v122.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v13.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v166.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v179.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v66.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v122.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v25.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v51.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v56.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v195.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v112.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v82.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v48.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v59.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v150.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v136.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v106.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v38.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v34.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v102.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v49.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v8.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v19.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v69.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v65.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v112.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v87.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v38.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v132.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v134.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/1_v194.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v77.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v81.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v167.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v178.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v33.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v107.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/3_v53.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v28.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v81.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v47.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v145.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v159.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v116.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v10.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/7_v178.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v111.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v176.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v97.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v117.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/8_v33.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v41.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v161.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v69.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/6_v102.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/2_v10.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/4_v64.JPG
#   inflating: data_sequence_trial_2_200/train/losing_ground_rental_house/5_v20.JPG
# ...
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v25.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v48.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v141.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v179.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v32.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v185.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v4.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v167.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v94.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v54.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v122.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v29.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v66.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v40.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v65.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v107.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v99.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v193.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v123.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v53.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v195.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v119.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v178.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v197.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v182.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v85.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v17.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v176.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v77.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v177.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v77.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v164.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v146.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v48.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v92.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v45.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v49.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v146.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v150.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v51.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v38.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v167.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v123.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v36.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v18.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v190.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v3.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v127.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v103.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v198.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v42.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v85.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v125.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v32.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v178.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v69.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v8.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v17.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v143.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v141.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v79.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v83.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v96.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v49.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v39.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v68.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v92.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v8.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v188.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v128.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v17.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v47.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v42.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v13.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v106.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v192.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v112.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v93.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v47.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v121.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v18.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v37.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v89.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v27.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v156.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v71.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v117.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v1.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v60.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v88.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v135.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v134.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v126.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v115.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v24.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v5.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v144.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v65.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v24.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v92.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v6.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v9.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v68.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v50.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v150.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v27.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v151.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v173.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v157.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v81.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v72.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v14.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v129.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v174.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v6.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v82.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v198.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v107.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v78.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v13.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v63.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v75.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v122.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v62.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v9.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v82.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v109.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v110.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v110.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v187.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v34.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v133.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v12.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v22.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v124.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v85.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v15.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v95.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v105.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v96.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v127.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v19.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v73.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v132.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v148.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v143.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v178.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v52.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v29.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v87.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v160.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v193.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v15.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v3.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v118.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v98.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v196.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v172.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v198.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v100.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/3_v49.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v180.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v140.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v31.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v196.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v177.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v138.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/5_v113.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/4_v120.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v113.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/2_v91.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v123.JPG
#   inflating: data_sequence_trial_2_200/train/chained_for_life_garden/1_v111.JPG

# %% [markdown]
# # Transfer learning

# %% [markdown]
# ## Preprocessing data

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),

}

data_dir = '/content/data_sequence_trial_2_200'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'valid']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=64,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'valid']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'valid']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

print(dataset_sizes)
# Out:
# cuda:0
# {'train': 26203, 'valid': 6560}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ## Training model

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for i, (inputs, labels) in enumerate(dataloaders[phase]):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## VGG16

# %%
model_conv = torchvision.models.vgg16(pretrained=True)

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.classifier[6].in_features
model_conv.classifier[6] = nn.Linear(num_ftrs, len(class_names))

model_conv = model_conv.to(device)

# Freeze the layers except the final classifier layer
for param in model_conv.features.parameters():
    param.requires_grad = False

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.classifier[6].parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

model_conv= train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler,
                       num_epochs=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 0/9
# ----------
# train Loss: 1.6467 Acc: 0.6373
# valid Loss: 0.9204 Acc: 0.8233
#
# Epoch 1/9
# ----------
# train Loss: 0.8820 Acc: 0.8011
# valid Loss: 0.6950 Acc: 0.8497
#
# Epoch 2/9
# ----------

# %%
# Save the entire model
torch.save(model_conv, '/content/drive/MyDrive/cs406/TRECVID/checkpoints/best_model_aug-vgg16_200_2.pth')

# %%
# Load the model
loaded_model = torch.load('/content/drive/MyDrive/cs406/TRECVID/checkpoints/best_model_aug-vgg16_200_2.pth')

# If you want to use the loaded model for inference, make sure to set it to evaluation mode
loaded_model.eval()

# %% [markdown]
# ## MobilenetV2

# %%
model_conv = torchvision.models.mobilenet_v2(pretrained=True)

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.classifier[1].in_features
model_conv.classifier[1] = nn.Linear(num_ftrs, len(class_names))

model_conv = model_conv.to(device)

for param in model_conv.features.parameters():
    param.requires_grad = False

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.classifier[1].parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

model_conv= train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler,
                       num_epochs=10)

# %%
# Save the entire model
torch.save(model_conv, '/content/drive/MyDrive/TRECVID/checkpoints/best_model_aug-mobilenet_500_1.pth')

# Load the model
loaded_model = torch.load('/content/drive/MyDrive/TRECVID/checkpoints/best_model_aug-mobilenet_500_1.pth')

# If you want to use the loaded model for inference, make sure to set it to evaluation mode
loaded_model.eval()

# %% [markdown]
# ## ResNet-18

# %%
model_conv = torchvision.models.resnet18(pretrained=True)

count = 0

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, len(class_names))

model_conv = model_conv.to(device)
count = 0
m = 0;
for i in model_conv.children():
    m += 1
for i in model_conv.children():
    count += 1
    if count < m - 1:
        for j in i.parameters():
            j.requires_grad = False

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

model_conv= train_model(model_conv, criterion, optimizer_conv, exp_lr_scheduler,
                       num_epochs=10)

# %%
# Save the entire model
torch.save(model_conv, '/content/drive/MyDrive/TRECVID/checkpoints/best_model_aug-resnet_500_2.pth')

# %%
# Load the model
loaded_model = torch.load('/content/drive/MyDrive/TRECVID/checkpoints/best_model_aug-resnet_500_2.pth')

# If you want to use the loaded model for inference, make sure to set it to evaluation mode
loaded_model.eval()
